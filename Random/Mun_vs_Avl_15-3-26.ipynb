# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import re
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import os
import time
from unidecode import unidecode
import warnings
from mplsoccer.pitch import Pitch
import seaborn as sns
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from mplsoccer import VerticalPitch
from PIL import Image

# %%
match_html_path = r"C:\Users\K Raghunandan\Analyst\Matches\Manchester United 3-1 Aston Villa - Premier League 2025_2026 Live.html"
fotmob_matchId = 4813671

def extract_json_from_html(html_path, save_output=False):
    with open(html_path, 'r', encoding='utf-8') as html_file:
        html = html_file.read()

    regex_pattern = r'(?<=require\.config\.params\["args"\].=.)[\s\S]*?;'
    data_txt = re.findall(regex_pattern, html)[0]

    # add quotations for JSON parser
    data_txt = data_txt.replace('matchId', '"matchId"')
    data_txt = data_txt.replace('matchCentreData', '"matchCentreData"')
    data_txt = data_txt.replace('matchCentreEventTypeJson', '"matchCentreEventTypeJson"')
    data_txt = data_txt.replace('formationIdNameMappings', '"formationIdNameMappings"')
    data_txt = data_txt.replace('};', '}')

    if save_output:
        # save JSON data to txt
        output_file = open(f"{html_path}.txt", "wt", encoding='utf-8')
        n = output_file.write(data_txt)
        output_file.close()

    return data_txt

def extract_data_from_dict(data):
    # load data from json
    event_types_json = data["matchCentreEventTypeJson"]
    formation_mappings = data["formationIdNameMappings"]
    events_dict = data["matchCentreData"]["events"]
    teams_dict = {data["matchCentreData"]['home']['teamId']: data["matchCentreData"]['home']['name'],
                  data["matchCentreData"]['away']['teamId']: data["matchCentreData"]['away']['name']}
    players_dict = data["matchCentreData"]["playerIdNameDictionary"]
    # create players dataframe
    players_home_df = pd.DataFrame(data["matchCentreData"]['home']['players'])
    players_home_df["teamId"] = data["matchCentreData"]['home']['teamId']
    players_away_df = pd.DataFrame(data["matchCentreData"]['away']['players'])
    players_away_df["teamId"] = data["matchCentreData"]['away']['teamId']
    players_df = pd.concat([players_home_df, players_away_df])
    players_ids = data["matchCentreData"]["playerIdNameDictionary"]
    return events_dict, players_df, teams_dict

def get_short_name(full_name):
    if pd.isna(full_name):
        return full_name
    parts = full_name.split()
    if len(parts) == 1:
        return full_name  # No need for short name if there's only one word
    elif len(parts) == 2:
        return parts[0][0] + ". " + parts[1]
    else:
        return parts[0][0] + ". " + parts[1][0] + ". " + " ".join(parts[2:])

json_data_txt = extract_json_from_html(match_html_path)
data = json.loads(json_data_txt)
events_dict, players_df, teams_dict = extract_data_from_dict(data)

df = pd.DataFrame(events_dict)
dfp = pd.DataFrame(players_df)
dfp['shortName'] = dfp['name'].apply(get_short_name)

# %%
df['type'] = df['type'].str.extract(r"'displayName': '([^']+)")
df['outcomeType'] = df['outcomeType'].str.extract(r"'displayName': '([^']+)")
df['period'] = df['period'].str.extract(r"'displayName': '([^']+)")

# %%
df['teamName'] = df['teamId'].map(teams_dict)
team_names = list(teams_dict.values())
opposition_dict = {team_names[i]: team_names[1-i] for i in range(len(team_names))}
df['oppositionTeamName'] = df['teamName'].map(opposition_dict)

# %%
df['x'] = df['x']*1.2
df['y'] = df['y']*0.8
df['endX'] = df['endX']*1.2
df['endY'] = df['endY']*0.8
df['goalMouthY'] = df['goalMouthY']*0.8

# %%
columns_to_drop = ['height', 'weight', 'age', 'isManOfTheMatch', 'field', 'stats', 
                   'subbedInPlayerId', 'subbedOutPeriod', 
                   'subbedOutExpandedMinute', 'subbedInPeriod', 'subbedInExpandedMinute', 'subbedOutPlayerId', 
                   'teamId']
dfp.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#                 id  eventId  minute  second  teamId      x      y  \
# 0     2.911972e+09        3       0     0.0      32   0.00   0.00
# 1     2.911972e+09        3       0     0.0      24   0.00   0.00
# 2     2.911972e+09        4       0     0.0      24  60.00  40.00
# 3     2.911972e+09        5       0     5.0      24  23.76  32.00
# 4     2.912162e+09      791       0     8.0      24  36.60   3.68
# ...            ...      ...     ...     ...     ...    ...    ...
# 1473  2.912105e+09      824      98     9.0      32   0.00   0.00
# 1474  2.912106e+09      789       0     0.0      24   0.00   0.00
# 1475  2.912105e+09      825       0     0.0      32   0.00   0.00
# 1476  2.911909e+09        2       0     0.0      32   0.00   0.00
# 1477  2.911909e+09        2       0     0.0      24   0.00   0.00
#
#       expandedMinute period type  ... relatedPlayerId blockedX blockedY  \
# 0                  0    NaN  NaN  ...             NaN      NaN      NaN
# 1                  0    NaN  NaN  ...             NaN      NaN      NaN
# 2                  0    NaN  NaN  ...             NaN      NaN      NaN
# 3                  0    NaN  NaN  ...             NaN      NaN      NaN
# 4                  0    NaN  NaN  ...             NaN      NaN      NaN
# ...              ...    ...  ...  ...             ...      ...      ...
# 1473             100    NaN  NaN  ...             NaN      NaN      NaN
# 1474              10    NaN  NaN  ...             NaN      NaN      NaN
# 1475              10    NaN  NaN  ...             NaN      NaN      NaN
# 1476               0    NaN  NaN  ...             NaN      NaN      NaN
# 1477               0    NaN  NaN  ...             NaN      NaN      NaN
#
#       goalMouthZ  goalMouthY  isShot  cardType  isGoal     teamName  \
# 0            NaN         NaN     NaN       NaN     NaN      Man Utd
# 1            NaN         NaN     NaN       NaN     NaN  Aston Villa
# 2            NaN         NaN     NaN       NaN     NaN  Aston Villa
# 3            NaN         NaN     NaN       NaN     NaN  Aston Villa
# 4            NaN         NaN     NaN       NaN     NaN  Aston Villa
# ...          ...         ...     ...       ...     ...          ...
# 1473         NaN         NaN     NaN       NaN     NaN      Man Utd
# 1474         NaN         NaN     NaN       NaN     NaN  Aston Villa
# 1475         NaN         NaN     NaN       NaN     NaN      Man Utd
# 1476         NaN         NaN     NaN       NaN     NaN      Man Utd
# 1477         NaN         NaN     NaN       NaN     NaN  Aston Villa
#
#       oppositionTeamName
# 0            Aston Villa
# 1                Man Utd
# 2                Man Utd
# 3                Man Utd
# 4                Man Utd
# ...                  ...
# 1473         Aston Villa
# 1474             Man Utd
# 1475         Aston Villa
# 1476         Aston Villa
# 1477             Man Utd
#
# [1478 rows x 28 columns]

# %%
dfp
# Out:
#     playerId  shirtNo               name position isFirstEleven     shortName
# 0     402184       31      Senne Lammens       GK          True    S. Lammens
# 1     353418        2        Diogo Dalot       DR          True      D. Dalot
# 2     437299       15          Leny Yoro       DC          True       L. Yoro
# 3      99487        5      Harry Maguire       DC          True    H. Maguire
# 4     118244       23          Luke Shaw       DL          True       L. Shaw
# 5      88526       18           Casemiro      DMC          True      Casemiro
# 6     460260       37      Kobbie Mainoo      DMC          True     K. Mainoo
# 7     386634       16        Amad Diallo      AMR          True     A. Diallo
# 8     123761        8    Bruno Fernandes      AMC          True  B. Fernandes
# 9     362758       10      Matheus Cunha      AML          True      M. Cunha
# 10    353377       19       Bryan Mbeumo       FW          True     B. Mbeumo
# 11    424191       30     Benjamin Sesko      Sub           NaN      B. Sesko
# 12    408962       25      Manuel Ugarte      Sub           NaN     M. Ugarte
# 13    349932        3  Noussair Mazraoui      Sub           NaN   N. Mazraoui
# 14    345303       12     Tyrell Malacia      Sub           NaN    T. Malacia
# 15    383956       11     Joshua Zirkzee      Sub           NaN    J. Zirkzee
# 16    361707        1     Altay Bayindir      Sub           NaN   A. Bayindir
# 17    517341       26       Ayden Heaven      Sub           NaN     A. Heaven
# 18    343346        7        Mason Mount      Sub           NaN      M. Mount
# 19    563778       39     Tyler Fletcher      Sub           NaN   T. Fletcher
# 0     102248       23  Emiliano Martínez       GK          True   E. Martínez
# 1     408946       26     Lamare Bogarde       DR          True    L. Bogarde
# 2     123167        5       Tyrone Mings       DC          True      T. Mings
# 3     301440        4         Ezri Konsa       DC          True      E. Konsa
# 4      89925       12        Lucas Digne       DL          True      L. Digne
# 5     400815       24       Amadou Onana      DMC          True      A. Onana
# 6      92547        6       Ross Barkley      DMC          True    R. Barkley
# 7     362824       27      Morgan Rogers      AMR          True     M. Rogers
# 8     318449        7        John McGinn      AMC          True     J. McGinn
# 9     260592       10   Emiliano Buendía      AML          True    E. Buendía
# 10    148503       11      Ollie Watkins       FW          True    O. Watkins
# 11    337883       21       Douglas Luiz      Sub           NaN       D. Luiz
# 12    327682       31        Leon Bailey      Sub           NaN     L. Bailey
# 13    384134       22        Ian Maatsen      Sub           NaN    I. Maatsen
# 14    469329       16      Andrés García      Sub           NaN     A. García
# 15    317506       18      Tammy Abraham      Sub           NaN    T. Abraham
# 16     83824       40        Marco Bizot      Sub           NaN      M. Bizot
# 17    344259       14         Pau Torres      Sub           NaN     P. Torres
# 18    100008        3    Victor Lindelöf      Sub           NaN   V. Lindelöf
# 19    363982        9     Harvey Elliott      Sub           NaN    H. Elliott

# %%
df = df.merge(dfp, on='playerId', how='left')

# %%
df = df[
    ((df['x'].notna()) & 
    (df['y'].notna()) & 
    (df['endX'].notna()) & 
    (df['endY'].notna())) | 
    ((df['x'].notna()) & 
    (df['y'].notna()) & 
    (df['goalMouthY'].notna()))
]

# %%
df=df.reset_index()

# %%
df
# Out:
#       index            id  eventId  minute  second  teamId       x      y  \
# 0         2  2.911972e+09        4       0     0.0      24   60.00  40.00
# 1         3  2.911972e+09        5       0     5.0      24   23.76  32.00
# 2         4  2.912162e+09      791       0     8.0      24   36.60   3.68
# 3         7  2.911973e+09        5       0    52.0      32   34.68  66.96
# 4        10  2.911973e+09        8       0    54.0      24   34.92  19.04
# ...     ...           ...      ...     ...     ...     ...     ...    ...
# 1064   1465  2.912104e+09      783      97    55.0      24   70.80  28.64
# 1065   1467  2.912105e+09      784      98     1.0      24  101.76  14.64
# 1066   1468  2.912105e+09      785      98     4.0      24   85.68  21.12
# 1067   1469  2.912105e+09      821      98     5.0      32   14.16  37.76
# 1068   1470  2.912105e+09      822      98     6.0      32   26.88  52.08
#
#       expandedMinute period  ... isShot cardType isGoal     teamName  \
# 0                  0    NaN  ...    NaN      NaN    NaN  Aston Villa
# 1                  0    NaN  ...    NaN      NaN    NaN  Aston Villa
# 2                  0    NaN  ...    NaN      NaN    NaN  Aston Villa
# 3                  0    NaN  ...    NaN      NaN    NaN      Man Utd
# 4                  0    NaN  ...    NaN      NaN    NaN  Aston Villa
# ...              ...    ...  ...    ...      ...    ...          ...
# 1064              99    NaN  ...    NaN      NaN    NaN  Aston Villa
# 1065             100    NaN  ...    NaN      NaN    NaN  Aston Villa
# 1066             100    NaN  ...    NaN      NaN    NaN  Aston Villa
# 1067             100    NaN  ...    NaN      NaN    NaN      Man Utd
# 1068             100    NaN  ...    NaN      NaN    NaN      Man Utd
#
#       oppositionTeamName  shirtNo               name  position  isFirstEleven  \
# 0                Man Utd      7.0        John McGinn       AMC           True
# 1                Man Utd     23.0  Emiliano Martínez        GK           True
# 2                Man Utd     26.0     Lamare Bogarde        DR           True
# 3            Aston Villa     31.0      Senne Lammens        GK           True
# 4                Man Utd      6.0       Ross Barkley       DMC           True
# ...                  ...      ...                ...       ...            ...
# 1064             Man Utd     27.0      Morgan Rogers       AMR           True
# 1065             Man Utd     16.0      Andrés García       Sub            NaN
# 1066             Man Utd     24.0       Amadou Onana       DMC           True
# 1067         Aston Villa      2.0        Diogo Dalot        DR           True
# 1068         Aston Villa     30.0     Benjamin Sesko       Sub            NaN
#
#         shortName
# 0       J. McGinn
# 1     E. Martínez
# 2      L. Bogarde
# 3      S. Lammens
# 4      R. Barkley
# ...           ...
# 1064    M. Rogers
# 1065    A. García
# 1066     A. Onana
# 1067     D. Dalot
# 1068     B. Sesko
#
# [1069 rows x 34 columns]

# %%
df=df[["minute","second","x","y","endX","endY","teamName","shirtNo","position","shortName","goalMouthY","isShot","isGoal"]]

# %%
df
# Out:
#       minute  second       x      y    endX   endY     teamName  shirtNo  \
# 0          0     0.0   60.00  40.00   24.84  40.24  Aston Villa      7.0
# 1          0     5.0   23.76  32.00   39.48   4.48  Aston Villa     23.0
# 2          0     8.0   36.60   3.68   86.28   8.08  Aston Villa     26.0
# 3          0    52.0   34.68  66.96   85.08  60.96      Man Utd     31.0
# 4          0    54.0   34.92  19.04   45.96  31.76  Aston Villa      6.0
# ...      ...     ...     ...    ...     ...    ...          ...      ...
# 1064      97    55.0   70.80  28.64   93.00   6.64  Aston Villa     27.0
# 1065      98     1.0  101.76  14.64   85.68  21.12  Aston Villa     16.0
# 1066      98     4.0   85.68  21.12  106.32  45.28  Aston Villa     24.0
# 1067      98     5.0   14.16  37.76   26.88  51.92      Man Utd      2.0
# 1068      98     6.0   26.88  52.08   37.08  52.08      Man Utd     30.0
#
#      position    shortName  goalMouthY isShot isGoal
# 0         AMC    J. McGinn         NaN    NaN    NaN
# 1          GK  E. Martínez         NaN    NaN    NaN
# 2          DR   L. Bogarde         NaN    NaN    NaN
# 3          GK   S. Lammens         NaN    NaN    NaN
# 4         DMC   R. Barkley         NaN    NaN    NaN
# ...       ...          ...         ...    ...    ...
# 1064      AMR    M. Rogers         NaN    NaN    NaN
# 1065      Sub    A. García         NaN    NaN    NaN
# 1066      DMC     A. Onana         NaN    NaN    NaN
# 1067       DR     D. Dalot         NaN    NaN    NaN
# 1068      Sub     B. Sesko         NaN    NaN    NaN
#
# [1069 rows x 13 columns]

# %%
team1=df[df["teamName"]=="Man Utd"]
team1
# Out:
#       minute  second      x      y   endX   endY teamName  shirtNo position  \
# 3          0    52.0  34.68  66.96  85.08  60.96  Man Utd     31.0       GK
# 5          0    56.0  76.08  60.24  97.92  56.88  Man Utd     37.0      DMC
# 8          1     2.0  65.76  42.96  75.12  80.00  Man Utd      2.0       DR
# 10         1    19.0  54.12  72.96  84.48  42.08  Man Utd      5.0       DC
# 12         1    28.0  32.64  17.84  40.44  19.76  Man Utd      2.0       DR
# ...      ...     ...    ...    ...    ...    ...      ...      ...      ...
# 1056      97    25.0  41.88  27.68  39.24  44.24  Man Utd     25.0      Sub
# 1057      97    31.0  26.64  31.52  53.76  18.80  Man Utd      5.0       DC
# 1063      97    44.0   4.92  48.24  39.12  73.20  Man Utd     37.0      DMC
# 1067      98     5.0  14.16  37.76  26.88  51.92  Man Utd      2.0       DR
# 1068      98     6.0  26.88  52.08  37.08  52.08  Man Utd     30.0      Sub
#
#        shortName  goalMouthY isShot isGoal
# 3     S. Lammens         NaN    NaN    NaN
# 5      K. Mainoo         NaN    NaN    NaN
# 8       D. Dalot         NaN    NaN    NaN
# 10    H. Maguire         NaN    NaN    NaN
# 12      D. Dalot         NaN    NaN    NaN
# ...          ...         ...    ...    ...
# 1056   M. Ugarte         NaN    NaN    NaN
# 1057  H. Maguire         NaN    NaN    NaN
# 1063   K. Mainoo         NaN    NaN    NaN
# 1067    D. Dalot         NaN    NaN    NaN
# 1068    B. Sesko         NaN    NaN    NaN
#
# [553 rows x 13 columns]

# %%
team2=df[df["teamName"]=="Aston Villa"]
team2
# Out:
#       minute  second       x      y    endX   endY     teamName  shirtNo  \
# 0          0     0.0   60.00  40.00   24.84  40.24  Aston Villa      7.0
# 1          0     5.0   23.76  32.00   39.48   4.48  Aston Villa     23.0
# 2          0     8.0   36.60   3.68   86.28   8.08  Aston Villa     26.0
# 4          0    54.0   34.92  19.04   45.96  31.76  Aston Villa      6.0
# 6          0    59.0   24.36  30.80   46.44  31.12  Aston Villa      5.0
# ...      ...     ...     ...    ...     ...    ...          ...      ...
# 1061      97    39.0  107.28  42.64  115.32  32.24  Aston Villa     18.0
# 1062      97    42.0  117.24  30.24  113.88  30.24  Aston Villa     21.0
# 1064      97    55.0   70.80  28.64   93.00   6.64  Aston Villa     27.0
# 1065      98     1.0  101.76  14.64   85.68  21.12  Aston Villa     16.0
# 1066      98     4.0   85.68  21.12  106.32  45.28  Aston Villa     24.0
#
#      position    shortName  goalMouthY isShot isGoal
# 0         AMC    J. McGinn         NaN    NaN    NaN
# 1          GK  E. Martínez         NaN    NaN    NaN
# 2          DR   L. Bogarde         NaN    NaN    NaN
# 4         DMC   R. Barkley         NaN    NaN    NaN
# 6          DC     T. Mings         NaN    NaN    NaN
# ...       ...          ...         ...    ...    ...
# 1061      Sub   T. Abraham         NaN    NaN    NaN
# 1062      Sub      D. Luiz         NaN    NaN    NaN
# 1064      AMR    M. Rogers         NaN    NaN    NaN
# 1065      Sub    A. García         NaN    NaN    NaN
# 1066      DMC     A. Onana         NaN    NaN    NaN
#
# [516 rows x 13 columns]

# %%
firstSub1=75

# %%
team1=team1[team1["minute"]<firstSub1]
team1
# Out:
#      minute  second      x      y    endX   endY teamName  shirtNo position  \
# 3         0    52.0  34.68  66.96   85.08  60.96  Man Utd     31.0       GK
# 5         0    56.0  76.08  60.24   97.92  56.88  Man Utd     37.0      DMC
# 8         1     2.0  65.76  42.96   75.12  80.00  Man Utd      2.0       DR
# 10        1    19.0  54.12  72.96   84.48  42.08  Man Utd      5.0       DC
# 12        1    28.0  32.64  17.84   40.44  19.76  Man Utd      2.0       DR
# ..      ...     ...    ...    ...     ...    ...      ...      ...      ...
# 834      73    30.0  51.24  68.96   44.64  52.80  Man Utd     23.0       DL
# 835      73    31.0  46.08  50.88  110.88   2.24  Man Utd      5.0       DC
# 837      74    21.0  63.48   0.00   90.96   6.56  Man Utd      2.0       DR
# 838      74    29.0  90.36   4.64   85.44  13.44  Man Utd     19.0       FW
# 839      74    30.0  85.44  13.44   91.56  10.08  Man Utd     37.0      DMC
#
#       shortName  goalMouthY isShot isGoal
# 3    S. Lammens         NaN    NaN    NaN
# 5     K. Mainoo         NaN    NaN    NaN
# 8      D. Dalot         NaN    NaN    NaN
# 10   H. Maguire         NaN    NaN    NaN
# 12     D. Dalot         NaN    NaN    NaN
# ..          ...         ...    ...    ...
# 834     L. Shaw         NaN    NaN    NaN
# 835  H. Maguire         NaN    NaN    NaN
# 837    D. Dalot         NaN    NaN    NaN
# 838   B. Mbeumo         NaN    NaN    NaN
# 839   K. Mainoo         NaN    NaN    NaN
#
# [441 rows x 13 columns]

# %%
firstSub2=60

# %%
team2=team2[team2["minute"]<firstSub2]
team2
# Out:
#      minute  second       x      y    endX   endY     teamName  shirtNo  \
# 0         0     0.0   60.00  40.00   24.84  40.24  Aston Villa      7.0
# 1         0     5.0   23.76  32.00   39.48   4.48  Aston Villa     23.0
# 2         0     8.0   36.60   3.68   86.28   8.08  Aston Villa     26.0
# 4         0    54.0   34.92  19.04   45.96  31.76  Aston Villa      6.0
# 6         0    59.0   24.36  30.80   46.44  31.12  Aston Villa      5.0
# ..      ...     ...     ...    ...     ...    ...          ...      ...
# 703      57    54.0   66.72  11.20   88.68   2.08  Aston Villa     24.0
# 704      57    59.0   84.48   5.12   90.72  18.40  Aston Villa     27.0
# 705      58     0.0   90.72  18.40   82.80  19.68  Aston Villa      7.0
# 706      59    34.0   84.72  18.72  112.92  42.24  Aston Villa      7.0
# 707      59    37.0  112.92  42.24     NaN    NaN  Aston Villa      5.0
#
#     position    shortName  goalMouthY isShot isGoal
# 0        AMC    J. McGinn         NaN    NaN    NaN
# 1         GK  E. Martínez         NaN    NaN    NaN
# 2         DR   L. Bogarde         NaN    NaN    NaN
# 4        DMC   R. Barkley         NaN    NaN    NaN
# 6         DC     T. Mings         NaN    NaN    NaN
# ..       ...          ...         ...    ...    ...
# 703      DMC     A. Onana         NaN    NaN    NaN
# 704      AMR    M. Rogers         NaN    NaN    NaN
# 705      AMC    J. McGinn         NaN    NaN    NaN
# 706      AMC    J. McGinn         NaN    NaN    NaN
# 707       DC     T. Mings       30.56   True    NaN
#
# [335 rows x 13 columns]

# %%
response=requests.get("https://www.sofascore.com/football/match/aston-villa-manchester-united/KP#id:14023994,tab:statistics")

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
    'referer': 'https://www.sofascore.com/football/match/aston-villa-manchester-united/KP',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36',
}

url='https://www.sofascore.com/api/v1/event/14023994/shotmap'

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
shots=response.json()

# %%
df_shots=pd.json_normalize(shots["shotmap"])

# %%
df_shots
# Out:
#     isHome shotType   situation    bodyPart goalMouthLocation        xg  \
# 0    False     miss   set-piece  right-foot              left  0.034046
# 1     True    block    assisted   left-foot        low-centre  0.034887
# 2     True     miss  fast-break  right-foot             right  0.239789
# 3     True     goal     regular  right-foot          low-left  0.075159
# 4     True     goal    assisted  right-foot         low-right  0.177168
# 5    False     goal      corner   left-foot          low-left  0.113119
# 6    False     save     regular  right-foot       high-centre  0.192288
# 7    False     miss    assisted        head             right  0.038977
# 8     True     save    assisted       other       high-centre  0.057339
# 9    False     miss   set-piece        head             right  0.361109
# 10   False    block   free-kick  right-foot        low-centre  0.048039
# 11   False    block    assisted  right-foot        low-centre  0.024669
# 12    True     goal      corner        head          low-left  0.069396
# 13    True     save  fast-break   left-foot        low-centre  0.052555
# 14    True     miss      corner  right-foot              left  0.043458
# 15    True    block    assisted  right-foot          low-left  0.030014
# 16    True     miss    assisted  right-foot        high-right  0.047915
# 17    True     miss  fast-break  right-foot             right  0.026354
# 18    True     miss    assisted   left-foot              high  0.107062
# 19    True    block    assisted  right-foot        low-centre  0.043655
# 20    True     miss      corner   left-foot              left  0.031802
# 21   False     miss    assisted   left-foot        high-right  0.059158
# 22    True     save      corner        head          low-left  0.043422
# 23    True    block    assisted   left-foot        low-centre  0.023962
# 24   False     miss    assisted        head              left  0.138024
#
#         xgot       id  time  addedTime  ...  draw.end.y  draw.goal.x  \
# 0   0.000000  6895263    90        7.0  ...           0         40.3
# 1   0.000000  6895256    90        6.0  ...           0         48.6
# 2   0.000000  6895170    85        NaN  ...           0         72.4
# 3   0.508013  6895105    81        NaN  ...           0         47.2
# 4   0.471050  6895033    71        NaN  ...           0         52.7
# 5   0.526625  6894999    64        NaN  ...           0         47.2
# 6   0.467487  6894968    63        NaN  ...           0         51.6
# 7   0.000000  6894970    63        NaN  ...           0         61.2
# 8   0.035150  6894956    62        NaN  ...           0         50.0
# 9   0.000000  6894837    60        NaN  ...           0         61.8
# 10  0.000000  6894814    57        NaN  ...           0         49.5
# 11  0.000000  6894795    54        NaN  ...           0         49.0
# 12  0.686487  6894786    53        NaN  ...           0         46.4
# 13  0.025053  6894751    52        NaN  ...           0         50.5
# 14  0.000000  6894688    51        NaN  ...           0         38.3
# 15  0.000000  6894682    51        NaN  ...           0         48.0
# 16  0.000000  6894660    48        NaN  ...           0         60.0
# 17  0.000000  6894437    43        NaN  ...           0         61.2
# 18  0.000000  6894355    38        NaN  ...           0         45.5
# 19  0.000000  6894351    37        NaN  ...           0         49.5
# 20  0.000000  6894340    35        NaN  ...           0          6.4
# 21  0.000000  6894214    24        NaN  ...           0         63.0
# 22  0.483603  6894202    22        NaN  ...           0         46.6
# 23  0.000000  6894186    20        NaN  ...           0         49.6
# 24  0.000000  6894174     9        NaN  ...           0         24.2
#
#     draw.goal.y  blockCoordinates.x blockCoordinates.y blockCoordinates.z  \
# 0          80.6                 NaN                NaN                NaN
# 1          81.0                13.4               34.8                0.0
# 2          98.6                 NaN                NaN                NaN
# 3          81.0                 NaN                NaN                NaN
# 4          93.0                 NaN                NaN                NaN
# 5          93.0                 NaN                NaN                NaN
# 6          69.6                 2.3               53.8                0.0
# 7          84.7                 9.4               56.1                0.0
# 8          76.6                 4.0               55.8                0.0
# 9          69.4                 NaN                NaN                NaN
# 10         81.0                15.3               48.9                0.0
# 11         81.0                 8.0               69.3                0.0
# 12         85.4                 NaN                NaN                NaN
# 13         82.9                 1.4               47.3                0.0
# 14         87.5                 NaN                NaN                NaN
# 15         81.0                14.7               63.7                0.0
# 16         34.7                 NaN                NaN                NaN
# 17         91.7                 NaN                NaN                NaN
# 18         26.4                 NaN                NaN                NaN
# 19         81.0                13.7               63.5                0.0
# 20         94.4                 1.9                9.4                0.0
# 21         59.7                 NaN                NaN                NaN
# 22         92.4                 1.2               52.0                0.0
# 23         81.0                18.2               57.8                0.0
# 24         98.6                 5.0               34.8                0.0
#
#    goalkeeper.sofascoreId draw.block.x draw.block.y goalType
# 0                     NaN          NaN          NaN      NaN
# 1             EmiMartínez         34.8         13.4      NaN
# 2             EmiMartínez          NaN          NaN      NaN
# 3             EmiMartínez          NaN          NaN  regular
# 4             EmiMartínez          NaN          NaN  regular
# 5                     NaN          NaN          NaN  regular
# 6                     NaN         53.8          2.3      NaN
# 7                     NaN         56.1          9.4      NaN
# 8             EmiMartínez         55.8          4.0      NaN
# 9                     NaN          NaN          NaN      NaN
# 10                    NaN         48.9         15.3      NaN
# 11                    NaN         69.3          8.0      NaN
# 12            EmiMartínez          NaN          NaN  regular
# 13            EmiMartínez         47.3          1.4      NaN
# 14            EmiMartínez          NaN          NaN      NaN
# 15            EmiMartínez         63.7         14.7      NaN
# 16            EmiMartínez          NaN          NaN      NaN
# 17            EmiMartínez          NaN          NaN      NaN
# 18            EmiMartínez          NaN          NaN      NaN
# 19            EmiMartínez         63.5         13.7      NaN
# 20            EmiMartínez          9.4          1.9      NaN
# 21                    NaN          NaN          NaN      NaN
# 22            EmiMartínez         52.0          1.2      NaN
# 23            EmiMartínez         57.8         18.2      NaN
# 24                    NaN         34.8          5.0      NaN
#
# [25 rows x 67 columns]

# %%
df_shots=df_shots.sort_values("time").reset_index()
df_shots
# Out:
#     index  isHome shotType   situation    bodyPart goalMouthLocation  \
# 0      24   False     miss    assisted        head              left
# 1      23    True    block    assisted   left-foot        low-centre
# 2      22    True     save      corner        head          low-left
# 3      21   False     miss    assisted   left-foot        high-right
# 4      20    True     miss      corner   left-foot              left
# 5      19    True    block    assisted  right-foot        low-centre
# 6      18    True     miss    assisted   left-foot              high
# 7      17    True     miss  fast-break  right-foot             right
# 8      16    True     miss    assisted  right-foot        high-right
# 9      15    True    block    assisted  right-foot          low-left
# 10     14    True     miss      corner  right-foot              left
# 11     13    True     save  fast-break   left-foot        low-centre
# 12     12    True     goal      corner        head          low-left
# 13     11   False    block    assisted  right-foot        low-centre
# 14     10   False    block   free-kick  right-foot        low-centre
# 15      9   False     miss   set-piece        head             right
# 16      8    True     save    assisted       other       high-centre
# 17      7   False     miss    assisted        head             right
# 18      6   False     save     regular  right-foot       high-centre
# 19      5   False     goal      corner   left-foot          low-left
# 20      4    True     goal    assisted  right-foot         low-right
# 21      3    True     goal     regular  right-foot          low-left
# 22      2    True     miss  fast-break  right-foot             right
# 23      1    True    block    assisted   left-foot        low-centre
# 24      0   False     miss   set-piece  right-foot              left
#
#           xg      xgot       id  time  ...  draw.end.y  draw.goal.x  \
# 0   0.138024  0.000000  6894174     9  ...           0         24.2
# 1   0.023962  0.000000  6894186    20  ...           0         49.6
# 2   0.043422  0.483603  6894202    22  ...           0         46.6
# 3   0.059158  0.000000  6894214    24  ...           0         63.0
# 4   0.031802  0.000000  6894340    35  ...           0          6.4
# 5   0.043655  0.000000  6894351    37  ...           0         49.5
# 6   0.107062  0.000000  6894355    38  ...           0         45.5
# 7   0.026354  0.000000  6894437    43  ...           0         61.2
# 8   0.047915  0.000000  6894660    48  ...           0         60.0
# 9   0.030014  0.000000  6894682    51  ...           0         48.0
# 10  0.043458  0.000000  6894688    51  ...           0         38.3
# 11  0.052555  0.025053  6894751    52  ...           0         50.5
# 12  0.069396  0.686487  6894786    53  ...           0         46.4
# 13  0.024669  0.000000  6894795    54  ...           0         49.0
# 14  0.048039  0.000000  6894814    57  ...           0         49.5
# 15  0.361109  0.000000  6894837    60  ...           0         61.8
# 16  0.057339  0.035150  6894956    62  ...           0         50.0
# 17  0.038977  0.000000  6894970    63  ...           0         61.2
# 18  0.192288  0.467487  6894968    63  ...           0         51.6
# 19  0.113119  0.526625  6894999    64  ...           0         47.2
# 20  0.177168  0.471050  6895033    71  ...           0         52.7
# 21  0.075159  0.508013  6895105    81  ...           0         47.2
# 22  0.239789  0.000000  6895170    85  ...           0         72.4
# 23  0.034887  0.000000  6895256    90  ...           0         48.6
# 24  0.034046  0.000000  6895263    90  ...           0         40.3
#
#     draw.goal.y  blockCoordinates.x  blockCoordinates.y blockCoordinates.z  \
# 0          98.6                 5.0                34.8                0.0
# 1          81.0                18.2                57.8                0.0
# 2          92.4                 1.2                52.0                0.0
# 3          59.7                 NaN                 NaN                NaN
# 4          94.4                 1.9                 9.4                0.0
# 5          81.0                13.7                63.5                0.0
# 6          26.4                 NaN                 NaN                NaN
# 7          91.7                 NaN                 NaN                NaN
# 8          34.7                 NaN                 NaN                NaN
# 9          81.0                14.7                63.7                0.0
# 10         87.5                 NaN                 NaN                NaN
# 11         82.9                 1.4                47.3                0.0
# 12         85.4                 NaN                 NaN                NaN
# 13         81.0                 8.0                69.3                0.0
# 14         81.0                15.3                48.9                0.0
# 15         69.4                 NaN                 NaN                NaN
# 16         76.6                 4.0                55.8                0.0
# 17         84.7                 9.4                56.1                0.0
# 18         69.6                 2.3                53.8                0.0
# 19         93.0                 NaN                 NaN                NaN
# 20         93.0                 NaN                 NaN                NaN
# 21         81.0                 NaN                 NaN                NaN
# 22         98.6                 NaN                 NaN                NaN
# 23         81.0                13.4                34.8                0.0
# 24         80.6                 NaN                 NaN                NaN
#
#    goalkeeper.sofascoreId draw.block.x draw.block.y goalType
# 0                     NaN         34.8          5.0      NaN
# 1             EmiMartínez         57.8         18.2      NaN
# 2             EmiMartínez         52.0          1.2      NaN
# 3                     NaN          NaN          NaN      NaN
# 4             EmiMartínez          9.4          1.9      NaN
# 5             EmiMartínez         63.5         13.7      NaN
# 6             EmiMartínez          NaN          NaN      NaN
# 7             EmiMartínez          NaN          NaN      NaN
# 8             EmiMartínez          NaN          NaN      NaN
# 9             EmiMartínez         63.7         14.7      NaN
# 10            EmiMartínez          NaN          NaN      NaN
# 11            EmiMartínez         47.3          1.4      NaN
# 12            EmiMartínez          NaN          NaN  regular
# 13                    NaN         69.3          8.0      NaN
# 14                    NaN         48.9         15.3      NaN
# 15                    NaN          NaN          NaN      NaN
# 16            EmiMartínez         55.8          4.0      NaN
# 17                    NaN         56.1          9.4      NaN
# 18                    NaN         53.8          2.3      NaN
# 19                    NaN          NaN          NaN  regular
# 20            EmiMartínez          NaN          NaN  regular
# 21            EmiMartínez          NaN          NaN  regular
# 22            EmiMartínez          NaN          NaN      NaN
# 23            EmiMartínez         34.8         13.4      NaN
# 24                    NaN          NaN          NaN      NaN
#
# [25 rows x 68 columns]

# %%
df_shots=df_shots[["isHome","shotType","xg","time","player.shortName","player.jerseyNumber","playerCoordinates.x","playerCoordinates.y",
        "goalMouthCoordinates.x","goalMouthCoordinates.y"]]

# %%
df_shots["playerCoordinates.x"]=df_shots["playerCoordinates.x"]*1.2
df_shots["playerCoordinates.y"]=df_shots["playerCoordinates.y"]*0.8
df_shots["goalMouthCoordinates.x"]=df_shots["goalMouthCoordinates.x"]*1.2
df_shots["goalMouthCoordinates.y"]=df_shots["goalMouthCoordinates.y"]*0.8
# Out:
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\3668136620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.x"]=df_shots["playerCoordinates.x"]*1.2
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\3668136620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"]=df_shots["playerCoordinates.y"]*0.8
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\3668136620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["goalMouthCoordinates.x"]=df_shots["goalMouthCoordinates.x"]*1.2
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\3668136620.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["goalMouthCoordinates.y"]=df_shots["goalMouthCoordinates.y"]*0.8

# %%
for x in range(len(df_shots["playerCoordinates.x"])):
    if (df_shots["isHome"][x]==False):
        df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
    if (df_shots["isHome"][x]==True):
        df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# Out:
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\4112479664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shots["playerCoordinates.y"][x]=80 - df_shots["playerCoordinates.y"][x]

# %%
team1_shots=df_shots[df_shots["isHome"]==True]
team1_shots
# Out:
#     isHome shotType        xg  time player.shortName player.jerseyNumber  \
# 1     True    block  0.023962    20     B. Fernandes                   8
# 2     True     save  0.043422    22        A. Diallo                  16
# 4     True     miss  0.031802    35        B. Mbeumo                  19
# 5     True    block  0.043655    37         Casemiro                  18
# 6     True     miss  0.107062    38         D. Dalot                   2
# 7     True     miss  0.026354    43     B. Fernandes                   8
# 8     True     miss  0.047915    48        A. Diallo                  16
# 9     True    block  0.030014    51     B. Fernandes                   8
# 10    True     miss  0.043458    51         M. Cunha                  10
# 11    True     save  0.052555    52        B. Mbeumo                  19
# 12    True     goal  0.069396    53         Casemiro                  18
# 16    True     save  0.057339    62         D. Dalot                   2
# 20    True     goal  0.177168    71         M. Cunha                  10
# 21    True     goal  0.075159    81         B. Šeško                  30
# 22    True     miss  0.239789    85         B. Šeško                  30
# 23    True    block  0.034887    90        A. Diallo                  16
#
#     playerCoordinates.x  playerCoordinates.y  goalMouthCoordinates.x  \
# 1                 32.76                30.56                     0.0
# 2                 10.92                34.40                     0.0
# 4                 24.24                29.04                     0.0
# 5                 19.80                26.88                     0.0
# 6                 13.32                30.24                     0.0
# 7                 31.32                55.04                     0.0
# 8                 13.44                21.92                     0.0
# 9                 23.64                24.80                     0.0
# 10                25.56                49.04                     0.0
# 11                17.76                54.72                     0.0
# 12                 4.92                32.08                     0.0
# 16                12.12                30.00                     0.0
# 20                12.12                52.80                     0.0
# 21                11.04                45.52                     0.0
# 22                18.24                49.92                     0.0
# 23                19.68                54.56                     0.0
#
#     goalMouthCoordinates.y
# 1                    40.32
# 2                    42.72
# 4                    74.88
# 5                    40.40
# 6                    43.60
# 7                    31.04
# 8                    32.00
# 9                    41.60
# 10                   49.36
# 11                   39.60
# 12                   42.88
# 16                   40.00
# 20                   37.84
# 21                   42.24
# 22                   22.08
# 23                   41.12

# %%
team2_shots=df_shots[df_shots["isHome"]==False]
team2_shots
# Out:
#     isHome shotType        xg  time player.shortName player.jerseyNumber  \
# 0    False     miss  0.138024     9       E. Buendía                  10
# 3    False     miss  0.059158    24        J. McGinn                   7
# 13   False    block  0.024669    54        M. Rogers                  27
# 14   False    block  0.048039    57       E. Buendía                  10
# 15   False     miss  0.361109    60         T. Mings                   5
# 17   False     miss  0.038977    63        L. Bailey                  31
# 18   False     save  0.192288    63         A. Onana                  24
# 19   False     goal  0.113119    64       R. Barkley                   6
# 24   False     miss  0.034046    90        M. Rogers                  27
#
#     playerCoordinates.x  playerCoordinates.y  goalMouthCoordinates.x  \
# 0                  8.40                37.52                     0.0
# 3                 23.16                46.48                     0.0
# 13                11.76                20.88                     0.0
# 14                32.28                41.20                     0.0
# 15                 7.08                42.24                     0.0
# 17                14.04                40.96                     0.0
# 18                11.76                32.96                     0.0
# 19                12.72                34.00                     0.0
# 24                28.20                43.12                     0.0
#
#     goalMouthCoordinates.y
# 0                    60.64
# 3                    29.60
# 13                   40.80
# 14                   40.40
# 15                   30.56
# 17                   31.04
# 18                   38.72
# 19                   42.24
# 24                   47.76

# %%
a_xG=[0]
h_xG=[0]
a_min=[0]
h_min=[0]

for x in range(len(df_shots["playerCoordinates.x"])):
    if (df_shots["isHome"][x]==True):
        h_xG.append(df_shots["xg"][x])
        h_min.append(df_shots["time"][x])
    if (df_shots["isHome"][x]==False):
        a_xG.append(df_shots["xg"][x])
        a_min.append(df_shots["time"][x])

# %%
def nums_cumulative_sum(nums_list):
    return [sum(nums_list[:i+1]) for i in range(len(nums_list))]

a_cum=nums_cumulative_sum(a_xG)
h_cum=nums_cumulative_sum(h_xG)

# %%
a_total=round(a_cum[-1],2)
h_total=round(h_cum[-1],2)

# %%
def create_passnetwork(df, ax,color):
    df["passer"]=df["shirtNo"]
    df["recipient"]=df["shirtNo"].shift(-1)

    pas=pd.to_numeric(df["passer"],downcast="integer")
    rec=pd.to_numeric(df["recipient"],downcast="integer")

    df["passer"]=pas
    df["recipient"]=rec

    df=df.drop(["goalMouthY","isShot","isGoal"],axis=1)

    average_locations=df.groupby("passer").agg({"x":["mean"],"y":["mean","count"]})
    average_locations.columns=["x","y","count"]
    average_locations

    pass_between = (
    df
    .groupby(["passer", "recipient"])
    .size()
    .reset_index(name="pass_count")
    )

    pass_between = pass_between.merge(average_locations, left_on='passer', right_index=True)
    pass_between = pass_between.merge(average_locations, left_on='recipient', right_index=True, suffixes=['', '_end'])

    pass_between=pass_between[pass_between["pass_count"]>3]

    pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#EAEAEA', line_color='#3A3A3A')
    pitch.draw(ax=ax)
    plt.gca().invert_xaxis()

    arrows=pitch.arrows(pass_between.x,
                        pass_between.y,
                        pass_between.x_end,
                        pass_between.y_end,
                        ax=ax,
                        width=4.2,
                        headwidth=4.2,
                        color=color,
                        alpha=.5)
    
    nodes=pitch.scatter(average_locations.x,
                    average_locations.y,
                    s=500,
                    color="#d3d3d3",
                    edgecolor="black",
                    linewidth=2.5,
                    alpha=1,
                    ax=ax)

    for passer, row in average_locations.iterrows():
        pitch.annotate(
            str(passer),
            xy=(row['x'], row['y']),
            ha='center',
            va='center',
            fontsize=9,
            color='black',
            weight='bold',
            ax=ax
        )

# %%
def create_xg_flowchart(df, ax, h_color, a_color):
    ax.patch.set_facecolor("#EAEAEA")
    
    plt.xticks([0,15,30,45,60,75,90])
    plt.xlabel("Minutes")
    plt.ylabel("xG")

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    df['cumulative_xG'] = df.groupby('isHome')['xg'].cumsum()

    ax.step(x=a_min,y=a_cum,where="post",color=a_color)
    ax.step(x=h_min,y=h_cum,where="post",color=h_color)

    for x in range(len(df["playerCoordinates.x"])):
        if (df["isHome"][x]==True):
            if df["shotType"][x]=="goal":
                plt.scatter(y=df["cumulative_xG"][x],x=df["time"][x],color="#EAEAEA",s=100,edgecolors=h_color,zorder=5)
                ax.text(
                    df['time'][x],
                    df['cumulative_xG'][x] + 0.09,
                    df['player.shortName'][x],
                    ha='center',
                    va='center',
                    fontfamily='monospace',
                    fontsize=8,
                    zorder=10
                )
                ax.text(
                    df['time'][x],
                    df['cumulative_xG'][x] + 0.05,
                    str(df['time'][x])+"'",
                    ha='center',
                    va='center',
                    fontfamily='monospace',
                    fontsize=8,
                    zorder=10
                )
        if (df["isHome"][x]==False):
            if df["shotType"][x]=="goal":
                plt.scatter(y=df["cumulative_xG"][x],x=df["time"][x],color="#EAEAEA",s=100,edgecolors=a_color)
                ax.text(
                    df['time'][x],
                    df['cumulative_xG'][x] + 0.09,
                    df['player.shortName'][x],
                    ha='center',
                    va='center',
                    fontfamily='monospace',
                    fontsize=8,
                    zorder=10
                )
                ax.text(
                    df['time'][x],
                    df['cumulative_xG'][x] + 0.05,
                    str(df['time'][x])+"'",
                    ha='center',
                    va='center',
                    fontfamily='monospace',
                    fontsize=8,
                    zorder=10
                )

# %%
def create_shotmap(df, ax, color):
    pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#EAEAEA', line_color='#3A3A3A',half=True)
    pitch.draw(ax=ax, constrained_layout=True, tight_layout=False)
    plt.gca().invert_yaxis()

    ax.set_xlim(0,80)
    ax.set_ylim(0,45)

    for x in df.to_dict(orient='records'):
        if x['shotType'] == 'goal':
            pitch.plot((x["playerCoordinates.x"],x["goalMouthCoordinates.x"]),
                       (x["playerCoordinates.y"],x["goalMouthCoordinates.y"]),
                       color=color,
                       ax=ax,
                       alpha=0.7)
        pitch.scatter(
            x=x["playerCoordinates.x"], y=x["playerCoordinates.y"], ax=ax, 
            s=500 * x['xg'], 
            facecolor=color if x['shotType'] == 'goal' else "#EAEAEA", 
            edgecolors=color, alpha=0.7
        )

# %%
fig = plt.figure(figsize=(15,12))

ax1=fig.add_axes([0.25, 0.8, 0.15, 0.15])
team1_img=Image.open("C:/Users/K Raghunandan/Analyst/Logos/Premier League/Manchester United.png")
ax1.imshow(team1_img)
ax1.axis("off")

ax2=fig.add_axes([0.6, 0.775, 0.10, 0.10])
league_img=Image.open("C:/Users/K Raghunandan/Analyst/Logos/Premier League/PREM LOGO (2).png")
ax2.imshow(league_img)
ax2.axis("off")

ax3=fig.add_axes([0.925, 0.8, 0.15, 0.15])
team2_img=Image.open("C:/Users/K Raghunandan/Analyst/Logos/Premier League/Aston Villa.png")
ax3.imshow(team2_img)
ax3.axis("off")

ax4=fig.add_axes([.15,.3,.3,.45])
create_passnetwork(team1,ax4, "#DA291C")
ax4.set_title("Manchester United Passing Network\n Until 75' minute")

ax5=fig.add_axes([.5,.1,.3,.35])
create_xg_flowchart(df_shots, ax5, "#DA291C", "#670E36")
ax5.set_title("xG Flow Chart")

plt.text(
    0.5, -0.15, "Data Source: Whoscored, Sofascore | Viz: @Kandula Raghunandan",
    ha="center", va="center",
    transform=plt.gca().transAxes,
    fontsize=10, color="black"
)

ax6=fig.add_axes([.85,.3,.3,.45])
create_passnetwork(team2,ax6, "#670E36")
ax6.set_title("Aston Villa Passing Network\n Until 60' minute")

ax7=fig.add_axes([.15,.05,.3,.2])
create_shotmap(team1_shots,ax7, "#DA291C")
ax7.set_title("Manchester United Shotmap")

ax8=fig.add_axes([.85,.05,.3,.2])
create_shotmap(team2_shots,ax8, "#670E36")
ax8.set_title("Aston Villa Shotmap")

ax9 = fig.add_axes([.5,.3,.3,.5])
ax9.set_facecolor("#f7f7f7")
ax9.axis("off")

ax9.text(0.5, 0.9, "Match Stats", ha="center", va="center",
         fontsize=16, fontweight="bold",color="#343434")

labels = ["Possession", "Shots", "Shots on Target", "xG", "Big Chances", "Passes"]

y_positions = [0.8, 0.725, 0.65, 0.575, 0.50, 0.425]

home_vals = ["52%", 16, 6, 1.10, 3, 410]
away_vals = ["48%", 9, 2, 1.00, 3, 376]

for label, y, n_val, u_val in zip(labels, y_positions, home_vals, away_vals):

    ax9.text(0.5, y, label, ha="center", fontsize=15)
    ax9.text(0.15, y, str(n_val), ha="right", fontsize=15,color="#DA020E")
    ax9.text(0.85, y, str(u_val), ha="left", fontsize=15,color="#670E36")


fig.text(0.65, 0.945, "Manchester United 3 - 1 Aston Villa", fontsize=20, fontweight='bold', color='#343434', ha="center", va="center")
fig.text(0.65, 0.91, "Premier League | Matchweek 30 | Old Trafford", fontsize=16, color='#343434', ha="center", va="center")
fig.text(0.65, 0.875, "Match Dashboard", fontsize=15, color='#343434', ha="center", va="center" )


fig.savefig("C:/Users/K Raghunandan/Analyst/Matches/Manchester United 3-1 Aston Villa - Premier League 2025_2026 Live_files/New folder/match_dashboard.png", bbox_inches='tight')
# Out:
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["passer"]=df["shirtNo"]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["recipient"]=df["shirtNo"].shift(-1)
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["passer"]=pas
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["recipient"]=rec
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\3893633159.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_xG'] = df.groupby('isHome')['xg'].cumsum()
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["passer"]=df["shirtNo"]
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["recipient"]=df["shirtNo"].shift(-1)
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["passer"]=pas
# C:\Users\K Raghunandan\AppData\Local\Temp\ipykernel_16568\1998340895.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["recipient"]=rec
