# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar
from scipy import stats
import math
from mplsoccer import PyPizza,add_image,FontManager

# %%
df_dembele=pd.read_html("https://fbref.com/en/players/b19db005/scout/365_m1/Ousmane-Dembele-Scouting-Report",
                attrs={"id":"scout_summary_AM"})[0]

# %%
df_dembele
# Out:
#               Standard Stats
#                    Statistic Per 90 Percentile
# 0          Non-Penalty Goals   0.79       99.0
# 1       npxG: Non-Penalty xG   0.71       99.0
# 2                Shots Total   4.60       99.0
# 3                    Assists   0.36       92.0
# 4   xAG: Exp. Assisted Goals   0.34       95.0
# 5                 npxG + xAG   1.04       99.0
# 6      Shot-Creating Actions   5.86       97.0
# 7                        NaN    NaN        NaN
# 8           Passes Attempted  55.84       95.0
# 9          Pass Completion %  78.8%       67.0
# 10        Progressive Passes   7.18       97.0
# 11       Progressive Carries   6.55       99.0
# 12       Successful Take-Ons   1.99       74.0
# 13         Touches (Att Pen)   8.01       96.0
# 14    Progressive Passes Rec  11.42       91.0
# 15                       NaN    NaN        NaN
# 16                   Tackles   0.60        3.0
# 17             Interceptions   0.23       12.0
# ...

# %%
df_dembele.columns=df_dembele.columns.droplevel(0)

# %%
df_dembele
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.79        99.0
# 1       npxG: Non-Penalty xG   0.71        99.0
# 2                Shots Total   4.60        99.0
# 3                    Assists   0.36        92.0
# 4   xAG: Exp. Assisted Goals   0.34        95.0
# 5                 npxG + xAG   1.04        99.0
# 6      Shot-Creating Actions   5.86        97.0
# 7                        NaN    NaN         NaN
# 8           Passes Attempted  55.84        95.0
# 9          Pass Completion %  78.8%        67.0
# 10        Progressive Passes   7.18        97.0
# 11       Progressive Carries   6.55        99.0
# 12       Successful Take-Ons   1.99        74.0
# 13         Touches (Att Pen)   8.01        96.0
# 14    Progressive Passes Rec  11.42        91.0
# 15                       NaN    NaN         NaN
# 16                   Tackles   0.60         3.0
# 17             Interceptions   0.23        12.0
# 18                    Blocks   0.17         1.0
# ...

# %%
df_dembele=df_dembele.drop([15,16,17,18,19,20,7])

# %%
df_dembele
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.79        99.0
# 1       npxG: Non-Penalty xG   0.71        99.0
# 2                Shots Total   4.60        99.0
# 3                    Assists   0.36        92.0
# 4   xAG: Exp. Assisted Goals   0.34        95.0
# 5                 npxG + xAG   1.04        99.0
# 6      Shot-Creating Actions   5.86        97.0
# 8           Passes Attempted  55.84        95.0
# 9          Pass Completion %  78.8%        67.0
# 10        Progressive Passes   7.18        97.0
# 11       Progressive Carries   6.55        99.0
# 12       Successful Take-Ons   1.99        74.0
# 13         Touches (Att Pen)   8.01        96.0
# 14    Progressive Passes Rec  11.42        91.0

# %%
df_dembele=df_dembele.reset_index()

# %%
df_dembele=df_dembele.drop("index",axis=1)
df_dembele
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.79        99.0
# 1       npxG: Non-Penalty xG   0.71        99.0
# 2                Shots Total   4.60        99.0
# 3                    Assists   0.36        92.0
# 4   xAG: Exp. Assisted Goals   0.34        95.0
# 5                 npxG + xAG   1.04        99.0
# 6      Shot-Creating Actions   5.86        97.0
# 7           Passes Attempted  55.84        95.0
# 8          Pass Completion %  78.8%        67.0
# 9         Progressive Passes   7.18        97.0
# 10       Progressive Carries   6.55        99.0
# 11       Successful Take-Ons   1.99        74.0
# 12         Touches (Att Pen)   8.01        96.0
# 13    Progressive Passes Rec  11.42        91.0

# %%
df_yamal=pd.read_html("https://fbref.com/en/players/82ec26c1/scout/365_m1/Lamine-Yamal-Scouting-Report",
                attrs={"id":"scout_summary_AM"})[0]

# %%
df_yamal
# Out:
#               Standard Stats
#                    Statistic Per 90 Percentile
# 0          Non-Penalty Goals   0.27       53.0
# 1       npxG: Non-Penalty xG   0.32       83.0
# 2                Shots Total   4.89       99.0
# 3                    Assists   0.32       88.0
# 4   xAG: Exp. Assisted Goals   0.33       94.0
# 5                 npxG + xAG   0.66       92.0
# 6      Shot-Creating Actions   5.81       96.0
# 7                        NaN    NaN        NaN
# 8           Passes Attempted  48.70       86.0
# 9          Pass Completion %  74.6%       39.0
# 10        Progressive Passes   4.81       75.0
# 11       Progressive Carries   6.01       96.0
# 12       Successful Take-Ons   5.44       99.0
# 13         Touches (Att Pen)   7.38       94.0
# 14    Progressive Passes Rec  13.09       96.0
# 15                       NaN    NaN        NaN
# 16                   Tackles   1.22       45.0
# 17             Interceptions   0.45       56.0
# ...

# %%
df_yamal.columns=df_yamal.columns.droplevel(0)

# %%
df_yamal
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.27        53.0
# 1       npxG: Non-Penalty xG   0.32        83.0
# 2                Shots Total   4.89        99.0
# 3                    Assists   0.32        88.0
# 4   xAG: Exp. Assisted Goals   0.33        94.0
# 5                 npxG + xAG   0.66        92.0
# 6      Shot-Creating Actions   5.81        96.0
# 7                        NaN    NaN         NaN
# 8           Passes Attempted  48.70        86.0
# 9          Pass Completion %  74.6%        39.0
# 10        Progressive Passes   4.81        75.0
# 11       Progressive Carries   6.01        96.0
# 12       Successful Take-Ons   5.44        99.0
# 13         Touches (Att Pen)   7.38        94.0
# 14    Progressive Passes Rec  13.09        96.0
# 15                       NaN    NaN         NaN
# 16                   Tackles   1.22        45.0
# 17             Interceptions   0.45        56.0
# 18                    Blocks   0.52         9.0
# ...

# %%
df_yamal=df_yamal.drop([7,15,16,17,18,19,20])

# %%
df_yamal
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.27        53.0
# 1       npxG: Non-Penalty xG   0.32        83.0
# 2                Shots Total   4.89        99.0
# 3                    Assists   0.32        88.0
# 4   xAG: Exp. Assisted Goals   0.33        94.0
# 5                 npxG + xAG   0.66        92.0
# 6      Shot-Creating Actions   5.81        96.0
# 8           Passes Attempted  48.70        86.0
# 9          Pass Completion %  74.6%        39.0
# 10        Progressive Passes   4.81        75.0
# 11       Progressive Carries   6.01        96.0
# 12       Successful Take-Ons   5.44        99.0
# 13         Touches (Att Pen)   7.38        94.0
# 14    Progressive Passes Rec  13.09        96.0

# %%
df_yamal=df_yamal.reset_index()

# %%
df_yamal=df_yamal.drop("index",axis=1)
df_yamal
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.27        53.0
# 1       npxG: Non-Penalty xG   0.32        83.0
# 2                Shots Total   4.89        99.0
# 3                    Assists   0.32        88.0
# 4   xAG: Exp. Assisted Goals   0.33        94.0
# 5                 npxG + xAG   0.66        92.0
# 6      Shot-Creating Actions   5.81        96.0
# 7           Passes Attempted  48.70        86.0
# 8          Pass Completion %  74.6%        39.0
# 9         Progressive Passes   4.81        75.0
# 10       Progressive Carries   6.01        96.0
# 11       Successful Take-Ons   5.44        99.0
# 12         Touches (Att Pen)   7.38        94.0
# 13    Progressive Passes Rec  13.09        96.0

# %%
df_raphina=pd.read_html("https://fbref.com/en/players/3423f250/scout/365_m1/Raphinha-Scouting-Report",
                attrs={"id":"scout_summary_AM"})[0]

# %%
df_raphina
# Out:
#               Standard Stats
#                    Statistic Per 90 Percentile
# 0          Non-Penalty Goals   0.63       99.0
# 1       npxG: Non-Penalty xG   0.50       99.0
# 2                Shots Total   3.68       98.0
# 3                    Assists   0.40       94.0
# 4   xAG: Exp. Assisted Goals   0.44       99.0
# 5                 npxG + xAG   0.93       99.0
# 6      Shot-Creating Actions   5.51       93.0
# 7                        NaN    NaN        NaN
# 8           Passes Attempted  46.95       80.0
# 9          Pass Completion %  72.9%       27.0
# 10        Progressive Passes   4.01       60.0
# 11       Progressive Carries   3.31       47.0
# 12       Successful Take-Ons   1.45       44.0
# 13         Touches (Att Pen)   5.60       77.0
# 14    Progressive Passes Rec  11.30       90.0
# 15                       NaN    NaN        NaN
# 16                   Tackles   1.24       47.0
# 17             Interceptions   0.40       46.0
# ...

# %%
df_raphina.columns=df_raphina.columns.droplevel(0)

# %%
df_raphina
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.63        99.0
# 1       npxG: Non-Penalty xG   0.50        99.0
# 2                Shots Total   3.68        98.0
# 3                    Assists   0.40        94.0
# 4   xAG: Exp. Assisted Goals   0.44        99.0
# 5                 npxG + xAG   0.93        99.0
# 6      Shot-Creating Actions   5.51        93.0
# 7                        NaN    NaN         NaN
# 8           Passes Attempted  46.95        80.0
# 9          Pass Completion %  72.9%        27.0
# 10        Progressive Passes   4.01        60.0
# 11       Progressive Carries   3.31        47.0
# 12       Successful Take-Ons   1.45        44.0
# 13         Touches (Att Pen)   5.60        77.0
# 14    Progressive Passes Rec  11.30        90.0
# 15                       NaN    NaN         NaN
# 16                   Tackles   1.24        47.0
# 17             Interceptions   0.40        46.0
# 18                    Blocks   0.87        47.0
# ...

# %%
df_raphina=df_raphina.drop([7,15,16,17,18,19,20])

# %%
df_raphina=df_raphina.reset_index()
df_raphina
# Out:
#     index                 Statistic Per 90  Percentile
# 0       0         Non-Penalty Goals   0.63        99.0
# 1       1      npxG: Non-Penalty xG   0.50        99.0
# 2       2               Shots Total   3.68        98.0
# 3       3                   Assists   0.40        94.0
# 4       4  xAG: Exp. Assisted Goals   0.44        99.0
# 5       5                npxG + xAG   0.93        99.0
# 6       6     Shot-Creating Actions   5.51        93.0
# 7       8          Passes Attempted  46.95        80.0
# 8       9         Pass Completion %  72.9%        27.0
# 9      10        Progressive Passes   4.01        60.0
# 10     11       Progressive Carries   3.31        47.0
# 11     12       Successful Take-Ons   1.45        44.0
# 12     13         Touches (Att Pen)   5.60        77.0
# 13     14    Progressive Passes Rec  11.30        90.0

# %%
df_raphina=df_raphina.drop("index",axis=1)
df_raphina
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.63        99.0
# 1       npxG: Non-Penalty xG   0.50        99.0
# 2                Shots Total   3.68        98.0
# 3                    Assists   0.40        94.0
# 4   xAG: Exp. Assisted Goals   0.44        99.0
# 5                 npxG + xAG   0.93        99.0
# 6      Shot-Creating Actions   5.51        93.0
# 7           Passes Attempted  46.95        80.0
# 8          Pass Completion %  72.9%        27.0
# 9         Progressive Passes   4.01        60.0
# 10       Progressive Carries   3.31        47.0
# 11       Successful Take-Ons   1.45        44.0
# 12         Touches (Att Pen)   5.60        77.0
# 13    Progressive Passes Rec  11.30        90.0

# %%
df_vitinha=pd.read_html("https://fbref.com/en/players/3b029691/scout/365_m1/Vitinha-Scouting-Report",
                attrs={"id":"scout_summary_MF"})[0]

# %%
df_vitinha
# Out:
#               Standard Stats
#                    Statistic  Per 90 Percentile
# 0          Non-Penalty Goals    0.13       75.0
# 1       npxG: Non-Penalty xG    0.07       55.0
# 2                Shots Total    1.43       79.0
# 3                    Assists    0.13       73.0
# 4   xAG: Exp. Assisted Goals    0.12       71.0
# 5                 npxG + xAG    0.19       63.0
# 6      Shot-Creating Actions    3.49       88.0
# 7                        NaN     NaN        NaN
# 8           Passes Attempted  102.41       99.0
# 9          Pass Completion %   92.9%       99.0
# 10        Progressive Passes    8.54       95.0
# 11       Progressive Carries    2.19       86.0
# 12       Successful Take-Ons    1.31       94.0
# 13         Touches (Att Pen)    1.03       44.0
# 14    Progressive Passes Rec    1.81       51.0
# 15                       NaN     NaN        NaN
# 16                   Tackles    1.48       16.0
# 17             Interceptions    0.93       44.0
# ...

# %%
df_vitinha.columns=df_vitinha.columns.droplevel(0)

# %%
df_vitinha=df_vitinha.drop([7,15,16,17,18,19,20])

# %%
df_vitinha=df_vitinha.reset_index()
df_vitinha
# Out:
#     index                 Statistic  Per 90  Percentile
# 0       0         Non-Penalty Goals    0.13        75.0
# 1       1      npxG: Non-Penalty xG    0.07        55.0
# 2       2               Shots Total    1.43        79.0
# 3       3                   Assists    0.13        73.0
# 4       4  xAG: Exp. Assisted Goals    0.12        71.0
# 5       5                npxG + xAG    0.19        63.0
# 6       6     Shot-Creating Actions    3.49        88.0
# 7       8          Passes Attempted  102.41        99.0
# 8       9         Pass Completion %   92.9%        99.0
# 9      10        Progressive Passes    8.54        95.0
# 10     11       Progressive Carries    2.19        86.0
# 11     12       Successful Take-Ons    1.31        94.0
# 12     13         Touches (Att Pen)    1.03        44.0
# 13     14    Progressive Passes Rec    1.81        51.0

# %%
df_vitinha=df_vitinha.drop("index",axis=1)
df_vitinha
# Out:
#                    Statistic  Per 90  Percentile
# 0          Non-Penalty Goals    0.13        75.0
# 1       npxG: Non-Penalty xG    0.07        55.0
# 2                Shots Total    1.43        79.0
# 3                    Assists    0.13        73.0
# 4   xAG: Exp. Assisted Goals    0.12        71.0
# 5                 npxG + xAG    0.19        63.0
# 6      Shot-Creating Actions    3.49        88.0
# 7           Passes Attempted  102.41        99.0
# 8          Pass Completion %   92.9%        99.0
# 9         Progressive Passes    8.54        95.0
# 10       Progressive Carries    2.19        86.0
# 11       Successful Take-Ons    1.31        94.0
# 12         Touches (Att Pen)    1.03        44.0
# 13    Progressive Passes Rec    1.81        51.0

# %%
df_salah=pd.read_html("https://fbref.com/en/players/e342ad68/scout/365_m1/Mohamed-Salah-Scouting-Report",
                attrs={"id":"scout_summary_AM"})[0]

# %%
df_salah
# Out:
#               Standard Stats
#                    Statistic Per 90 Percentile
# 0          Non-Penalty Goals   0.45       92.0
# 1       npxG: Non-Penalty xG   0.43       97.0
# 2                Shots Total   2.99       82.0
# 3                    Assists   0.45       98.0
# 4   xAG: Exp. Assisted Goals   0.37       97.0
# 5                 npxG + xAG   0.81       98.0
# 6      Shot-Creating Actions   3.78       59.0
# 7                        NaN    NaN        NaN
# 8           Passes Attempted  33.94       40.0
# 9          Pass Completion %  70.1%       15.0
# 10        Progressive Passes   3.87       55.0
# 11       Progressive Carries   3.96       63.0
# 12       Successful Take-Ons   1.18       29.0
# 13         Touches (Att Pen)   8.75       99.0
# 14    Progressive Passes Rec  12.99       95.0
# 15                       NaN    NaN        NaN
# 16                   Tackles   0.47        2.0
# 17             Interceptions   0.26       16.0
# ...

# %%
df_salah.columns=df_salah.columns.droplevel(0)

# %%
df_salah=df_salah.drop([7,15,16,17,18,19,20])

# %%
df_salah=df_salah.reset_index()
df_salah
# Out:
#     index                 Statistic Per 90  Percentile
# 0       0         Non-Penalty Goals   0.45        92.0
# 1       1      npxG: Non-Penalty xG   0.43        97.0
# 2       2               Shots Total   2.99        82.0
# 3       3                   Assists   0.45        98.0
# 4       4  xAG: Exp. Assisted Goals   0.37        97.0
# 5       5                npxG + xAG   0.81        98.0
# 6       6     Shot-Creating Actions   3.78        59.0
# 7       8          Passes Attempted  33.94        40.0
# 8       9         Pass Completion %  70.1%        15.0
# 9      10        Progressive Passes   3.87        55.0
# 10     11       Progressive Carries   3.96        63.0
# 11     12       Successful Take-Ons   1.18        29.0
# 12     13         Touches (Att Pen)   8.75        99.0
# 13     14    Progressive Passes Rec  12.99        95.0

# %%
df_salah=df_salah.drop("index",axis=1)
df_salah
# Out:
#                    Statistic Per 90  Percentile
# 0          Non-Penalty Goals   0.45        92.0
# 1       npxG: Non-Penalty xG   0.43        97.0
# 2                Shots Total   2.99        82.0
# 3                    Assists   0.45        98.0
# 4   xAG: Exp. Assisted Goals   0.37        97.0
# 5                 npxG + xAG   0.81        98.0
# 6      Shot-Creating Actions   3.78        59.0
# 7           Passes Attempted  33.94        40.0
# 8          Pass Completion %  70.1%        15.0
# 9         Progressive Passes   3.87        55.0
# 10       Progressive Carries   3.96        63.0
# 11       Successful Take-Ons   1.18        29.0
# 12         Touches (Att Pen)   8.75        99.0
# 13    Progressive Passes Rec  12.99        95.0

# %%
df_dembele["Statistic"]=["Np Goals","npxG","Total Shots","Assists","xAG","npxG+xAG","SCA","Passes Attemp.","Pass Comp %","Prog. Passes","Prog. Carries", 
                    "Succ. Takeons","Touches(Att Pen)","Prog. Passes Rec"]

# %%
params=df_dembele["Statistic"].values.tolist()
print(params)
# Out:
# ['Np Goals', 'npxG', 'Total Shots', 'Assists', 'xAG', 'npxG+xAG', 'SCA', 'Passes Attemp.', 'Pass Comp %', 'Prog. Passes', 'Prog. Carries', 'Succ. Takeons', 'Touches(Att Pen)', 'Prog. Passes Rec']

# %%
values_d=[]
for x in range(len(params)):
    values_d.append(df_dembele["Percentile"][x])
values_d
# Out:
# [np.float64(99.0),
#  np.float64(99.0),
#  np.float64(99.0),
#  np.float64(92.0),
#  np.float64(95.0),
#  np.float64(99.0),
#  np.float64(97.0),
#  np.float64(95.0),
#  np.float64(67.0),
#  np.float64(97.0),
#  np.float64(99.0),
#  np.float64(74.0),
#  np.float64(96.0),
#  np.float64(91.0)]

# %%
values_y=[]
for x in range(len(params)):
    values_y.append(df_yamal["Percentile"][x])
values_y
# Out:
# [np.float64(53.0),
#  np.float64(83.0),
#  np.float64(99.0),
#  np.float64(88.0),
#  np.float64(94.0),
#  np.float64(92.0),
#  np.float64(96.0),
#  np.float64(86.0),
#  np.float64(39.0),
#  np.float64(75.0),
#  np.float64(96.0),
#  np.float64(99.0),
#  np.float64(94.0),
#  np.float64(96.0)]

# %%
values_r=[]
for x in range(len(params)):
    values_r.append(df_raphina["Percentile"][x])
values_r
# Out:
# [np.float64(99.0),
#  np.float64(99.0),
#  np.float64(98.0),
#  np.float64(94.0),
#  np.float64(99.0),
#  np.float64(99.0),
#  np.float64(93.0),
#  np.float64(80.0),
#  np.float64(27.0),
#  np.float64(60.0),
#  np.float64(47.0),
#  np.float64(44.0),
#  np.float64(77.0),
#  np.float64(90.0)]

# %%
values_s=[]
for x in range(len(params)):
    values_s.append(df_salah["Percentile"][x])
values_s
# Out:
# [np.float64(92.0),
#  np.float64(97.0),
#  np.float64(82.0),
#  np.float64(98.0),
#  np.float64(97.0),
#  np.float64(98.0),
#  np.float64(59.0),
#  np.float64(40.0),
#  np.float64(15.0),
#  np.float64(55.0),
#  np.float64(63.0),
#  np.float64(29.0),
#  np.float64(99.0),
#  np.float64(95.0)]

# %%
values_v=[]
for x in range(len(params)):
    values_v.append(df_vitinha["Percentile"][x])
values_v
# Out:
# [np.float64(75.0),
#  np.float64(55.0),
#  np.float64(79.0),
#  np.float64(73.0),
#  np.float64(71.0),
#  np.float64(63.0),
#  np.float64(88.0),
#  np.float64(99.0),
#  np.float64(99.0),
#  np.float64(95.0),
#  np.float64(86.0),
#  np.float64(94.0),
#  np.float64(44.0),
#  np.float64(51.0)]

# %%
baker = PyPizza(
    params=params,                  # list of parameters
    straight_line_color="#000000",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=1,               # linewidth of last circle
    other_circle_lw=1,              # linewidth for other circles
    other_circle_ls="-."            # linestyle for other circles
)

# %%
#Dembele Pizza Plot
# plot pizza
fig, ax = baker.make_pizza(
    values_r,              # list of values
    figsize=(7, 9),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
fig.text(
    0.515, 0.97, "Ousmane Dembélé - Paris Saint-Germain (PSG)", size=18,
    ha="center",color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.942,
    "per 90 Percentile Rank vs Top 5 Leagues and UCL Wingers | Season 2024-25",
    size=15,
    ha="center",color="#000000"
)
# add credits
CREDIT_1 = "data: FBRef | Viz: @Raghunandan Kandula"

fig.text(
    0.99, 0.005, f"{CREDIT_1}", size=9,
    color="#000000",
    ha="right"
)
plt.savefig("C:/Users/K Raghunandan/Analyst/Results/Ballon Do'r 2025/Dembele Pizzaplot.png")
plt.tight_layout()
plt.show()

# %%
#Yamal Pizza Plot
# plot pizza
fig, ax = baker.make_pizza(
    values_y,              # list of values
    figsize=(7, 9),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
fig.text(
    0.515, 0.97, "Lamine Yamal - FC Barcelona (FCB)", size=18,
    ha="center",color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.942,
    "per 90 Percentile Rank vs Top 5 Leagues and UCL Wingers | Season 2024-25",
    size=15,
    ha="center",color="#000000"
)
# add credits
CREDIT_1 = "data: FBRef | Viz: @Raghunandan Kandula"

fig.text(
    0.99, 0.005, f"{CREDIT_1}", size=9,
    color="#000000",
    ha="right"
)
plt.savefig("C:/Users/K Raghunandan/Analyst/Results/Ballon Do'r 2025/Yamal Pizzaplot.png")
plt.tight_layout()
plt.show()

# %%
#Raphinha Pizza Plot
# plot pizza
fig, ax = baker.make_pizza(
    values_r,              # list of values
    figsize=(7, 9),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
fig.text(
    0.515, 0.97, "Raphinha - FC Barcelona (FCB)", size=18,
    ha="center",color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.942,
    "per 90 Percentile Rank vs Top 5 Leagues and UCL Wingers| Season 2024-25",
    size=15,
    ha="center",color="#000000"
)
# add credits
CREDIT_1 = "data: FBRef | Viz: @Raghunandan Kandula"

fig.text(
    0.99, 0.005, f"{CREDIT_1}", size=9,
    color="#000000",
    ha="right"
)
plt.savefig("C:/Users/K Raghunandan/Analyst/Results/Ballon Do'r 2025/Raphinha Pizzaplot.png")
plt.tight_layout()
plt.show()

# %%
#Vitinha Pizza Plot
# plot pizza
fig, ax = baker.make_pizza(
    values_v,              # list of values
    figsize=(7, 9),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
fig.text(
    0.515, 0.97, "Vitinha - Paris Saint-Germain (PSG)", size=18,
    ha="center",color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.942,
    "per 90 Percentile Rank vs Top 5 Leagues and UCL Midfielders | Season 2024-25",
    size=15,
    ha="center",color="#000000"
)
# add credits
CREDIT_1 = "data: FBRef | Viz: @Raghunandan Kandula"

fig.text(
    0.99, 0.005, f"{CREDIT_1}", size=9,
    color="#000000",
    ha="right"
)
plt.savefig("C:/Users/K Raghunandan/Analyst/Results/Ballon Do'r 2025/Vitinha Pizzaplot.png")
plt.tight_layout()
plt.show()

# %%
#Vitinha Pizza Plot
# plot pizza
fig, ax = baker.make_pizza(
    values_s,              # list of values
    figsize=(7, 9),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
fig.text(
    0.515, 0.97, "Mohamed Salah - Liverpool FC (LFC)", size=18,
    ha="center",color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.942,
    "per 90 Percentile Rank vs Top 5 Leagues and UCL Wingers | Season 2024-25",
    size=15,
    ha="center",color="#000000"
)
# add credits
CREDIT_1 = "data: FBRef | Viz: @Raghunandan Kandula"

fig.text(
    0.99, 0.005, f"{CREDIT_1}", size=9,
    color="#000000",
    ha="right"
)
plt.savefig("C:/Users/K Raghunandan/Analyst/Results/Ballon Do'r 2025/salah Pizzaplot.png")
plt.tight_layout()
plt.show()
