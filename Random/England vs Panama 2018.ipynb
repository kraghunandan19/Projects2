# %%
from statsbombpy import sb
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
from mplsoccer.pitch import VerticalPitch

# %%
competitions=sb.competitions()

# %%
print(competitions["competition_name"].unique())
# Out:
# ['1. Bundesliga' 'African Cup of Nations' 'Champions League'
#  'Copa America' 'Copa del Rey' "FA Women's Super League"
#  'FIFA U20 World Cup' 'FIFA World Cup' 'Indian Super league' 'La Liga'
#  'Liga Profesional' 'Ligue 1' 'Major League Soccer'
#  'North American League' 'NWSL' 'Premier League' 'Serie A' 'UEFA Euro'
#  'UEFA Europa League' "UEFA Women's Euro" "Women's World Cup"]

# %%
competitions[competitions["competition_name"]=="FIFA World Cup"]
# Out:
#     competition_id  season_id   country_name competition_name  \
# 29              43        106  International   FIFA World Cup
# 30              43          3  International   FIFA World Cup
# 31              43         55  International   FIFA World Cup
# 32              43         54  International   FIFA World Cup
# 33              43         51  International   FIFA World Cup
# 34              43        272  International   FIFA World Cup
# 35              43        270  International   FIFA World Cup
# 36              43        269  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 29               male              False                       True
# 30               male              False                       True
# 31               male              False                       True
# 32               male              False                       True
# 33               male              False                       True
# 34               male              False                       True
# 35               male              False                       True
# 36               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 29        2022  2024-12-16T10:15:11.055845  2024-12-16T10:21:13.710934
# 30        2018  2024-06-12T07:38:19.345758     2021-06-13T16:17:31.694
# 31        1990  2023-06-28T10:58:20.137929     2021-06-12T16:17:31.694
# 32        1986  2023-12-26T22:34:04.263530     2021-06-13T16:17:31.694
# 33        1974  2024-02-13T02:52:29.582599     2021-06-13T16:17:31.694
# 34        1970  2024-02-13T14:23:06.735299                        None
# 35        1962  2023-06-26T10:38:00.323984                        None
# 36        1958  2024-02-13T14:22:08.222297                        None
#
#            match_available_360             match_available
# 29  2024-12-16T10:21:13.710934  2024-12-16T10:15:11.055845
# 30                        None  2024-06-12T07:38:19.345758
# 31                        None  2023-06-28T10:58:20.137929
# 32                        None  2023-12-26T22:34:04.263530
# 33                        None  2024-02-13T02:52:29.582599
# 34                        None  2024-02-13T14:23:06.735299
# 35                        None  2023-06-26T10:38:00.323984
# 36                        None  2024-02-13T14:22:08.222297

# %%
matches=sb.matches(competition_id=43,season_id=3)
matches
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 0       7585  2018-07-03  20:00:00.000  International - FIFA World Cup   2018
# 1       7570  2018-06-28  20:00:00.000  International - FIFA World Cup   2018
# 2       7586  2018-07-03  16:00:00.000  International - FIFA World Cup   2018
# 3       7557  2018-06-25  20:00:00.000  International - FIFA World Cup   2018
# 4       7542  2018-06-20  14:00:00.000  International - FIFA World Cup   2018
# ..       ...         ...           ...                             ...    ...
# 59      7540  2018-06-19  20:00:00.000  International - FIFA World Cup   2018
# 60      8652  2018-07-07  20:00:00.000  International - FIFA World Cup   2018
# 61      7563  2018-06-26  16:00:00.000  International - FIFA World Cup   2018
# 62      7556  2018-06-24  17:00:00.000  International - FIFA World Cup   2018
# 63      7559  2018-06-25  16:00:00.000  International - FIFA World Cup   2018
#
#        home_team    away_team  home_score  away_score match_status  ...  \
# 0       Colombia      England           1           1    available  ...
# 1        England      Belgium           0           1    available  ...
# 2         Sweden  Switzerland           1           0    available  ...
# 3           Iran     Portugal           1           1    available  ...
# 4       Portugal      Morocco           1           0    available  ...
# ..           ...          ...         ...         ...          ...  ...
# 59        Russia        Egypt           3           1    available  ...
# 60        Russia      Croatia           2           2    available  ...
# 61       Denmark       France           0           0    available  ...
# 62         Japan      Senegal           2           2    available  ...
# 63  Saudi Arabia        Egypt           2           1    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 0   2021-06-13T16:17:31.694          4       Round of 16
# 1   2021-06-13T16:17:31.694          3       Group Stage
# 2   2021-06-13T16:17:31.694          4       Round of 16
# 3   2021-06-13T16:17:31.694          3       Group Stage
# 4   2021-06-13T16:17:31.694          2       Group Stage
# ..                      ...        ...               ...
# 59  2021-06-13T16:17:31.694          2       Group Stage
# 60  2021-06-13T16:17:31.694          5    Quarter-finals
# 61  2021-06-13T16:17:31.694          3       Group Stage
# 62  2021-06-13T16:17:31.694          2       Group Stage
# 63  2021-06-13T16:17:31.694          3       Group Stage
#
#                          stadium                        referee  \
# 0            Otkritie Bank Arena                    Mark Geiger
# 1            Stadion Kaliningrad                  Damir Skomina
# 2       Saint-Petersburg Stadium                  Damir Skomina
# 3                 Mordovia Arena                Enrique Cáceres
# 4               Stadion Luzhniki                    Mark Geiger
# ..                           ...                            ...
# 59      Saint-Petersburg Stadium                Enrique Cáceres
# 60  \tOlimpiyskiy Stadion Fisht                    Sandro Ricci
# 61              Stadion Luzhniki                   Sandro Ricci
# 62          \tEkaterinburg Arena                Gianluca Rocchi
# 63               Volgograd Arena  Wilmar Alexander Roldán Pérez
#
#                                 home_managers  \
# 0                        José Néstor Pekerman
# 1                            Gareth Southgate
# 2                          Jan Olof Andersson
# 3            Carlos Manuel Brito Leal Queiróz
# 4   Fernando Manuel Fernandes da Costa Santos
# ..                                        ...
# 59                       Stanislav Cherchesov
# 60                       Stanislav Cherchesov
# 61                       Åge Fridtjof Hareide
# 62                              Akira Nishino
# 63                 Juan Antonio Pizzi Torroja
#
#                                 away_managers data_version  \
# 0                            Gareth Southgate        1.0.2
# 1                   Roberto Martínez Montoliú        1.0.2
# 2                           Vladimir Petković        1.0.2
# 3   Fernando Manuel Fernandes da Costa Santos        1.0.2
# 4                                Hervé Renard        1.0.2
# ..                                        ...          ...
# 59                          Héctor Raúl Cúper        1.0.2
# 60                               Zlatko Dalić        1.0.2
# 61                           Didier Deschamps        1.0.2
# 62                                Aliou Cissé        1.0.2
# 63                          Héctor Raúl Cúper        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 0                   None                None
# 1                   None                None
# 2                   None                None
# 3                   None                None
# 4                   None                None
# ..                   ...                 ...
# 59                  None                None
# 60                  None                None
# 61                  None                None
# 62                  None                None
# 63                  None                None
#
# [64 rows x 22 columns]

# %%
eng_matches=matches[(matches["home_team"]=="England") | (matches["away_team"]=="England")]
eng_matches
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 0       7585  2018-07-03  20:00:00.000  International - FIFA World Cup   2018
# 1       7570  2018-06-28  20:00:00.000  International - FIFA World Cup   2018
# 5       8656  2018-07-11  20:00:00.000  International - FIFA World Cup   2018
# 6       7554  2018-06-24  14:00:00.000  International - FIFA World Cup   2018
# 20      7537  2018-06-18  20:00:00.000  International - FIFA World Cup   2018
# 54      8651  2018-07-07  16:00:00.000  International - FIFA World Cup   2018
# 58      8657  2018-07-14  16:00:00.000  International - FIFA World Cup   2018
#
#    home_team away_team  home_score  away_score match_status  ...  \
# 0   Colombia   England           1           1    available  ...
# 1    England   Belgium           0           1    available  ...
# 5    Croatia   England           2           1    available  ...
# 6    England    Panama           6           1    available  ...
# 20   Tunisia   England           1           2    available  ...
# 54    Sweden   England           0           2    available  ...
# 58   Belgium   England           2           0    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 0   2021-06-13T16:17:31.694          4       Round of 16
# 1   2021-06-13T16:17:31.694          3       Group Stage
# 5   2021-06-13T16:17:31.694          6       Semi-finals
# 6   2021-06-13T16:17:31.694          2       Group Stage
# 20  2021-06-13T16:17:31.694          1       Group Stage
# 54  2021-06-13T16:17:31.694          5    Quarter-finals
# 58  2021-06-13T16:17:31.694          7   3rd Place Final
#
#                                        stadium                        referee  \
# 0                          Otkritie Bank Arena                    Mark Geiger
# 1                          Stadion Kaliningrad                  Damir Skomina
# 5                             Stadion Luzhniki                   Cüneyt Çakιr
# 6   Stadion Nizhny Novgorod (Nizhniy Novgorod)                   Ghead Grisha
# 20                             Volgograd Arena  Wilmar Alexander Roldán Pérez
# 54                         \tSolidarnost Arena                  Björn Kuipers
# 58                    Saint-Petersburg Stadium                Alireza Faghani
#
#                 home_managers                 away_managers data_version  \
# 0        José Néstor Pekerman              Gareth Southgate        1.0.2
# 1            Gareth Southgate     Roberto Martínez Montoliú        1.0.2
# 5                Zlatko Dalić              Gareth Southgate        1.0.2
# 6            Gareth Southgate  Hernán Darío Gómez Jaramillo        1.0.2
# 20              Nabil Maâloul              Gareth Southgate        1.0.2
# 54         Jan Olof Andersson              Gareth Southgate        1.0.2
# 58  Roberto Martínez Montoliú              Gareth Southgate        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 0                   None                None
# 1                   None                None
# 5                   None                None
# 6                   None                None
# 20                  None                None
# 54                  None                None
# 58                  None                None
#
# [7 rows x 22 columns]

# %%
events=sb.events(match_id=7554)

# %%
events.head()
# Out:
#   bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                NaN                  NaN                            NaN
# 1                NaN                  NaN                            NaN
# 2                NaN                  NaN                            NaN
# 3                NaN                  NaN                            NaN
# 4                NaN                  NaN                            NaN
#
#   block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0              NaN             NaN                NaN                  NaN
# 1              NaN             NaN                NaN                  NaN
# 2              NaN             NaN                NaN                  NaN
# 3              NaN             NaN                NaN                  NaN
# 4              NaN             NaN                NaN                  NaN
#
#   counterpress dribble_outcome duel_outcome  ... substitution_outcome  \
# 0          NaN             NaN          NaN  ...                  NaN
# 1          NaN             NaN          NaN  ...                  NaN
# 2          NaN             NaN          NaN  ...                  NaN
# 3          NaN             NaN          NaN  ...                  NaN
# 4          NaN             NaN          NaN  ...                  NaN
#
#    substitution_outcome_id substitution_replacement  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   substitution_replacement_id  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                              tactics     team team_id  \
# 0  {'formation': 352, 'lineup': [{'player': {'id'...  England     768
# 1  {'formation': 4141, 'lineup': [{'player': {'id...   Panama     798
# 2                                                NaN  England     768
# 3                                                NaN   Panama     798
# 4                                                NaN  England     768
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
#
# [5 rows x 85 columns]

# %%
events.columns
# Out:
# Index(['bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive',
#        'carry_end_location', 'clearance_aerial_won', 'counterpress',
#        'dribble_outcome', 'duel_outcome', 'duel_type', 'duration',
#        'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_offensive', 'foul_committed_penalty',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'foul_won_penalty', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'injury_stoppage_in_chain',
#        'interception_outcome', 'location', 'match_id', 'minute',
#        'miscontrol_aerial_won', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_backheel', 'pass_body_part',
#        'pass_cross', 'pass_cut_back', 'pass_deflected', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_length', 'pass_outcome',
#        'pass_recipient', 'pass_recipient_id', 'pass_shot_assist',
#        'pass_switch', 'pass_technique', 'pass_through_ball', 'pass_type',
#        'period', 'play_pattern', 'player', 'player_id', 'position',
#        'possession', 'possession_team', 'possession_team_id', 'related_events',
#        'second', 'shot_body_part', 'shot_end_location', 'shot_first_time',
#        'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one',
#        'shot_open_goal', 'shot_outcome', 'shot_statsbomb_xg', 'shot_technique',
#        'shot_type', 'substitution_outcome', 'substitution_outcome_id',
#        'substitution_replacement', 'substitution_replacement_id', 'tactics',
#        'team', 'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
events=events[["team","type","minute","location","player","shot_outcome","shot_technique","shot_type","shot_statsbomb_xg","shot_end_location"]]
events=events[(events["team"]=="England") & (events["type"]=="Shot")].reset_index()

# %%
events.head(20)
# Out:
#     index     team  type  minute       location                  player  \
# 0    3495  England  Shot       7  [109.0, 42.0]             John Stones
# 1    3497  England  Shot      21  [109.0, 41.0]              Harry Kane
# 2    3498  England  Shot      35   [98.0, 34.0]           Jesse Lingard
# 3    3499  England  Shot      39  [115.0, 40.0]         Raheem Sterling
# 4    3500  England  Shot      39  [118.0, 36.0]             John Stones
# 5    3501  England  Shot      41  [100.0, 40.0]           Jesse Lingard
# 6    3502  England  Shot      45  [109.0, 41.0]              Harry Kane
# 7    3503  England  Shot      61   [97.0, 51.0]      Ruben Loftus-Cheek
# 8    3504  England  Shot      61  [105.0, 49.0]              Harry Kane
# 9    3506  England  Shot      72  [104.0, 45.0]  Jordan Brian Henderson
# 10   3509  England  Shot      81   [93.0, 30.0]         Raheem Sterling
#
#    shot_outcome shot_technique  shot_type  shot_statsbomb_xg  \
# 0          Goal         Normal  Open Play           0.134915
# 1          Goal         Normal    Penalty           0.783500
# 2          Goal         Normal  Open Play           0.056803
# 3         Saved         Normal  Open Play           0.433740
# 4          Goal         Normal  Open Play           0.567049
# 5       Blocked         Normal  Open Play           0.090632
# 6          Goal         Normal    Penalty           0.783500
# 7       Blocked         Normal  Open Play           0.034592
# 8          Goal         Normal  Open Play           0.200220
# 9         Off T         Volley  Open Play           0.061971
# 10        Off T         Normal  Open Play           0.021400
#
#      shot_end_location
# 0   [120.0, 37.2, 0.9]
# 1   [120.0, 36.6, 2.0]
# 2   [120.0, 43.8, 2.3]
# 3   [120.0, 40.5, 0.4]
# 4   [120.0, 37.2, 1.7]
# 5        [104.0, 41.0]
# 6   [120.0, 37.8, 1.6]
# 7        [104.0, 50.0]
# 8   [120.0, 39.7, 1.2]
# 9   [120.0, 35.0, 1.6]
# 10  [120.0, 45.4, 1.3]

# %%
events[["x","y"]]=pd.DataFrame(events.location.tolist(),index=events.index)
events[["x_end","y_end","height"]]=pd.DataFrame(events.shot_end_location.tolist(),index=events.index)
events["y_new"] = 120 - events["x"]
events["x_new"] = 80 - events["y"]
events["y_end_new"] = 120 - events["x_end"]
events["x_end_new"] = 80 - events["y_end"]

# %%
fig, ax=plt.subplots(figsize=(10.5,7))
fig.set_facecolor("#22312b")
ax.patch.set_facecolor("#22312b")

pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc',half=True)
pitch.draw(ax=ax, constrained_layout=True, tight_layout=False )
plt.gca().invert_yaxis()

ax.set_xlim(0,80)
ax.set_ylim(0,45)

for x in range(len(events["x"])):
    if events["shot_outcome"][x]=="Saved":
        plt.scatter(events["x_new"][x],events["y_new"][x],color="orange",s=events["shot_statsbomb_xg"][x]*800+100,alpha=.7)
    if events["shot_outcome"][x]=="Off T":
        plt.scatter(events["x_new"][x],events["y_new"][x],color="red",s=events["shot_statsbomb_xg"][x]*800+100,alpha=.7)
    if events["shot_outcome"][x]=="Blocked":
        plt.scatter(events["x_new"][x],events["y_new"][x],color="blue",s=events["shot_statsbomb_xg"][x]*800+100,alpha=.7)
    if events["shot_outcome"][x]=="Goal":
        plt.scatter(events["x_new"][x],events["y_new"][x],color="green",s=events["shot_statsbomb_xg"][x]*800+100,alpha=.7)

plt.title("England vs Panama WC 2018 Shotmap",color="white",size="20")
ax.text(2,40,"Goal",color="green")
ax.text(2,38,"Off Target",color="red")
ax.text(2,36,"Saved",color="orange")
ax.text(2,34,"Blocked",color="blue")
# Out:
# Text(2, 34, 'Blocked')
